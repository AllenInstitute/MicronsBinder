# %% [markdown]
# # Mitochondria visualization
# A brief notebook to demonstrate visualizing a cell id and its mitochondria

# %%
import pandas as pd
from nglui import statebuilder as sb

from lib import ngl

# %% [markdown]
# Reading the dataframe that links mitochondria to cell IDs

# %%
mitodf = pd.read_csv("data/pni_mito_cellswskel_v185_fullstats.csv")

# %%
mitodf.head()
# Out:
#    mito_id  mito_vx  ctr_pos_x_vx  ctr_pos_y_vx  ctr_pos_z_vx  bbox_beg_x_vx  \
# 0  1783325   527936         75186         43844          1430          74824
# 1  3272360   354680        101562         47000           241         101260
# 2  1776789   523452         74500         43210          1457          73444
# 3  2158922     4428         81214         54992          1230          81172
# 4  2158896    11196         81194         53124          2007          81142
#
#    bbox_beg_y_vx  bbox_beg_z_vx  bbox_end_x_vx  bbox_end_y_vx  bbox_end_z_vx  \
# 0          43668           1323          75472          44120           1561
# 1          46750            191         101750          47228            303
# 2          42632           1401          75636          43732           1564
# 3          54962           1228          81254          55018           1235
# 4          53096           2004          81250          53168           2014
#
# ...

# %%
img = sb.ImageLayerConfig(name="image", source=ngl.IMG_SOURCE)
seg = sb.SegmentationLayerConfig(name="seg", source=ngl.SEG_SOURCE,
                                 selected_ids_column="cellid",
                                 view_kws=dict(alpha_3d=0.25))  # some default transparency
mito = sb.SegmentationLayerConfig(name="mitochondria", source=ngl.MITO_SOURCE,
                                  selected_ids_column="mito_id")

# %%
builder = sb.StateBuilder(layers=[img, seg, mito],
                          view_kws=dict(layout="3d", zoom_3d=1000))

# %%
builder.render_state(mitodf[mitodf.cellid == 648518346349539593], return_as="html")
# Out:
# <a href="https://neuromancer-seung-import.appspot.com/#!%7B%22navigation%22:%7B%22pose%22:%7B%22position%22:%7B%22voxelSize%22:%5B4.0,4.0,40.0%5D%7D%7D,%22zoomFactor%22:2.0%7D,%22showSlices%22:false,%22layout%22:%223d%22,%22perspectiveZoom%22:1000.0,%22layers%22:%5B%7B%22type%22:%22image%22,%22source%22:%22precomputed://gs://neuroglancer/pinky100_v0/son_of_alignment_v15_rechunked%22,%22name%22:%22image%22%7D,%7B%22type%22:%22segmentation%22,%22source%22:%22precomputed://gs://microns_public_datasets/pinky100_v185/seg%22,%22name%22:%22seg%22,%22segments%22:%5B%22648518346349539593%22%5D,%22segmentColors%22:%7B%7D,%22objectAlpha%22:0.25%7D,%7B%22type%22:%22segmentation%22,%22source%22:%22precomputed://gs://neuroglancer/pinky100_v0/mito_seg_191220%22,%22name%22:%22mitochondria%22,%22segments%22:%5B%221470468%22,%222027528%22,%222164747%22,%222168847%22,%222306064%22,%222652180%22,%222879512%22,%222250776%22,%221800220%22,%223858460%22,%221208355%22,%222773029%22,%222525221%22,%221667109%
# ...
