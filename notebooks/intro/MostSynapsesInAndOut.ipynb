# %% [markdown]
# # Most synapses in and out
# This notebook demonstrates a few ways to work with the synapse tables we've generated. As a working example, it demonstrates how to find the neurons with the most input and output synapse predictions within a table. It also demonstrates how to view these cells and their synapses in neuroglancer, and points to further resources.

# %%
import nglui
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ### Reading data

# %% [markdown]
# read in the soma table to get IDs of cells with cell bodies in volume

# %%
soma_df = pd.read_csv('data/soma_valence_v185.csv')

# %%
soma_df.head()
# Out:
#     id cell_type             pt_position          pt_root_id  soma_x_nm  \
# 0   17         e  [103860  44385    891]  648518346349540057     415440
# 1  453         e     [84054 50604  1424]  648518346349538466     336216
# 2   35         e  [103728  54333    304]  648518346349538711     414912
# 3   74         e     [51543 57568   155]  648518346349538715     206172
# 4  231         e     [77197 61773   428]  648518346349537038     308788
#
#    soma_y_nm  soma_z_nm
# 0     415440    4154400
# 1     336216    3362160
# 2     414912    4149120
# 3     206172    2061720
# 4     308788    3087880

# %% [markdown]
# read in the synapse table

# %%
syn_df = pd.read_csv('data/pni_synapses_v185.csv')

# %% [markdown]
# It has 3.2 million rows

# %%
print(syn_df.shape)
# Out:
# (3239275, 16)

# %%
syn_df.head()
# Out:
#         id         pre_root_id        post_root_id  cleft_vx  ctr_pt_x_nm  \
# 0  2715757  648518346349538285  648518346349536759      1103       280784
# 1    12498  648518346342404863  648518346342414574        62       365832
# 2    12500  648518346342921567  648518346345323296        62       229144
# 3    12517  648518346342796822  648518346349537255       955       398452
# 4    12503  648518346342800412  648518346348190542       718       461868
#
#    ctr_pt_y_nm  ctr_pt_z_nm  pre_pos_x_vx  pre_pos_y_vx  pre_pos_z_vx  \
# 0       261896        40600         70050         65534          1015
# 1       292808        25800         91472         73196           645
# 2       155952        48080         57250         39028          1202
# 3       208560        50760         99538         52184          1276
# 4       245212        53560        115462         61350          1335
#
#    ctr_pos_x_vx  ctr_pos_y_vx  ctr_pos_z_vx  post_pos_x_vx  post_pos_y_vx  \
# 0         70196         65474          1015          70104          65602
# 1         91458         73202           645          91396          73216
# 2         57286         38988          1202          57312          38966
# 3         99613         52140          1269          99550          52098
# 4        115467         61303          1339         115468          61296
#
#    post_pos_z_vx
# 0           1015
# 1            645
# 2           1203
# 3           1276
# 4           1335

# %% [markdown]
# Lets filter for IDs with somas that are neurons

# %%
neuron_df=soma_df.query('cell_type == "i" | cell_type=="e"')

# %% [markdown]
# Use this list of IDs to filter all synapses to just those onto neurons

# %%
post_neuron_syn_df=syn_df[syn_df.post_root_id.isin(neuron_df.pt_root_id)]

# %% [markdown]
# 951,457 of 3.5 million synapses are onto cells with somas in the volume

# %%
post_neuron_syn_df.shape
# Out:
# (951457, 16)

# %% [markdown]
# ## Most inputs

# %% [markdown]
# Lets summarize the number of inputs these cells have

# %%
in_degree_df = post_neuron_syn_df.groupby('post_root_id').post_root_id.count()

# %%
in_degree_df.head()
# Out:
# post_root_id
# 648518346349477331     494
# 648518346349487432     434
# 648518346349487752     783
# 648518346349488919    2626
# 648518346349489861    1841
# Name: post_root_id, dtype: int64

# %% [markdown]
# Let's find the cell with the most inputs

# %%
max_input_neuron=in_degree_df.index[in_degree_df.argmax()]
print(max_input_neuron)
# Out:
# 648518346349538440

# %% [markdown]
# it has 5369 input synapses

# %%
in_degree_df[max_input_neuron]
# Out:
# 5369

# %% [markdown]
# Lets filter synapses to just those onto this one neuron

# %%
onto_cell_syn_df = post_neuron_syn_df.query(f'post_root_id == {max_input_neuron}').copy()

# %% [markdown]
# This illustrates how to setup a nglui pipeline to highlight synapses

# %% [markdown]
# ### Visualization: most inputs

# %%
from nglui.statebuilder import *
# get sources from the neuroglancer link
img_source = "precomputed://https://storage.googleapis.com/microns_public_datasets/pinky100_v0/son_of_alignment_v15_rechunked"
seg_source = "precomputed://gs://microns_public_datasets/pinky100_v185/seg"

# use nglui (www.github.com/seung-lab/NeuroglancerAnnotationUI) to setup a dataframe > neuroglancer link pipeline
img_layer = ImageLayerConfig(name='layer23',
                             source=img_source,
                             )
# we want the segmentation layer with our target neuron always on
seg_layer = SegmentationLayerConfig(name = 'seg',
                                    source = seg_source,
                                    fixed_ids=[max_input_neuron])

# need to consolidate the synapse position into a single column
onto_cell_syn_df.loc[:, 'ctr_pos']=onto_cell_syn_df.apply(lambda x: [x.ctr_pos_x_vx, x.ctr_pos_y_vx, x.ctr_pos_z_vx], axis=1).copy()

# setup a mapping rule for point annotations
syn_points = PointMapper(point_column='ctr_pos', linked_segmentation_column='pre_root_id')
# add these points linked to the segmentation layer name
syn_layer = AnnotationLayerConfig(name='synapses', mapping_rules=syn_points, linked_segmentation_layer='seg')

# %% [markdown]
# When you click the below link, you'll be taken to a neuroglancer visualization of the dataset.
#
# If you are unfamiliar with basic neuroglancer visualization, you should read a guide here (https://microns-explorer.org/visualization)
#
# There is also a fast intro (with movies!) written up here https://blog.eyewire.org/explore-cortical-neurons/.
#
# In this view, this code has setup a new layer (synapses).  It should open with the synapse layer details on the right hand side, where you can see a list of synapses.  To learn more about how to interact with this neuroglancer link , you can watch this below 5 minute video.

# %%
from IPython.lib.display import YouTubeVideo
YouTubeVideo('YTbu6vMljuE', width=800, height=600)

# %% [markdown]
# setup a state builder with this layer pipeline
#
# then render the state pipeline with the dataframe data
#
# returning the link as an html link

# %%
sb = StateBuilder([img_layer, seg_layer, syn_layer])
sb.render_state(onto_cell_syn_df, return_as='html')
# Out:
# <a href="https://neuromancer-seung-import.appspot.com/#!%7B%22navigation%22:%7B%22pose%22:%7B%22position%22:%7B%22voxelSize%22:%5B4.0,4.0,40.0%5D%7D%7D,%22zoomFactor%22:2.0%7D,%22showSlices%22:false,%22layout%22:%22xy-3d%22,%22perspectiveZoom%22:2000.0,%22layers%22:%5B%7B%22type%22:%22image%22,%22source%22:%22precomputed://https://storage.googleapis.com/microns_public_datasets/pinky100_v0/son_of_alignment_v15_rechunked%22,%22name%22:%22layer23%22%7D,%7B%22type%22:%22segmentation%22,%22source%22:%22precomputed://gs://microns_public_datasets/pinky100_v185/seg%22,%22name%22:%22seg%22,%22segments%22:%5B%22648518346349538440%22%5D,%22segmentColors%22:%7B%7D,%22selectedAlpha%22:0.3,%22objectAlpha%22:1.0,%22notSelectedAlpha%22:0.0%7D,%7B%22type%22:%22annotation%22,%22linkedSegmentationLayer%22:%22seg%22,%22filterBySegmentation%22:false,%22bracketShortcutsShowSegmentation%22:true,%22annotationSelectionShowsSegmentation%22:true,%22name%22:%22synapses%22,%22annotations%22:%5B%7B%22tagIds%22:%5B%5D,%22type%22:%22point%22,%22point%22:%5B101928.0,56584.0,1227.0%5D,%22id%22:%226d39cdcb5641a0fdb9e2d58dcadfbbb409f34e2c%22,%22segments%22:%5B%22648518346349535192%22%5D%7D,%7B%22tagIds%22:%5B%5D,%22type%22:%22point%22,%22point%22:%5B73990.0,54686.0,875.0%5D,%22id%22:%224f85e6e3f689e65894a0530c86f60e9bfc677e04%22,%22segments%22:%5B%22648518346349536679%22%5D%7D,%7B%22tagIds%22:%5B%5D,%22type%22:%22point%22,%22point%22:%5B91532.0,60682.0,412.0%5D,%22id%22:%22e1938ac5da2b3ed6e0de632e44a8cc47d1665411%22,%22segments%22:%5B%22648518346349535192%22%5D%7D,%7B%22tagIds%22:%5B%5D,%22type%22:%22point%22,%22point%22:%5B97796.0,50494.0,589.0%5D,%22id%22:%226e3925a027fdf85239f9094f85b8fbc0531aff5d%22,%22segments%22:%5B%22648518346349538218%22%5D%7D,%7B%22tagIds%22:%5B%5D,%22type%22:%22point%22,%22point%22:%5B99160.0,63022.0,1069.0%5D,%22id%22:%22a4a563dcbefbbda1e8e209bfac3e0838b8a8578c%22,%22segments%22:%5B%22648518346349537711%22%5D%7D,%7B%22tagIds%22:%5B%5D,%22type%22:%22point%22,%22point%22:%5B93476.0,47452.0,1656.0%5D,%22id%22:%225c34558463f868b5cab01b5757ab623c3f802e5a%22,%22segments%22:%5B%22648518346349537956%22%5D%7D,%7B%22tagIds%22:%5B%5D,%22type%22:%22point%22,%22point%22:%5B81396.0,62712.0,502.0%5D,%22id%22:%226e3c255e5e281ee622c092ad91d9914908d8dc04%22,%22segments%22:%5B%22648518346349537956%22%5D%7D,%7B%22tagIds%22:%5B%5D,%22type%22:%22point%22,%22point%22:%5B93130.0,61702.0,331.0%5D,%22id%22:%226e57219112f0e48e0740033407b3cef007f77132%22,%22segments%22:%5B%22648518346349538194%22%5D%7D,%7B%22tagIds%22:%5B%5D,%22type%22:%22point%22,%22point%22:%5B79954.0,62470.0,494.0%5D,%22id%22:%22820fac02bf525308783d1c4de4b8ac4c3665ba9a%22,%22segments%22:%5B%22648518346349537724%22%5D%7D,%7B%22tagIds%22:%5B%5D,%22type%22:%22point%22,%22point%22:%5B81286.0,38116.0,1894.0%5D,%22id%22:%223d8749adbdfe8215f129e5a8fb9d3c0782a8dd71%22,%22segments%22:%5B%22648518346346310490%22%5D%7D,%7B%22tagIds%22:%5B%5D,%22type%22:%22point%22,%22point%22:%5B81244.0,37082.0,1918.0%5D,%22id%22:%22ef271e616dda8314a8d51a0f2bfe2b374d8ccd57%22,%22segments%22:%5B%22648518346347678030%22%5D%7D,%7B%22tagIds%22:%5B%5D,%22type%22:%22point%22,%22point%22:%5B81450.0,37894.0,1834.0%5D,%22id%22:%22330ca72b1c0dbbf69efd117bd89f42194f1b4527%22,%22segments%22:%5B%22648518346346596101%22%5D%7D,%7B%22tagIds%22:%5B%5D,%22type%22:%22point%22,%22point%22:%5B81588.0,37336.0,1894.0%5D,%22id%22:%22744985bbb8527f444d213606d1135683f450baa4%22,%22segments%22:%5B%22648518346347679369%22%5D%7D,%7B%22tagIds%22:%5B%5D,%22type%22:%22point%22,%22point%22:%5B81589.0,37209.0,1901.0%5D,%22id%22:%229f467bd4256ba35686b934891aaa823c1982c14a%22,%22segments%22:%5B%22648518346347678047%22%5D%7D,%7B%22tagIds%22:%5B%5D,%22type%22:%22point%22,%22point%22:%5B81156.0,50699.0,1255.0%5D,%22id%22:%224ee7c60011f95885d374a617558537c1e947ee25%22,%22segments%22:%5B%22648518346349528965%22%5D%7D,%7B%22tagIds%22:%5B%5D,%22type%22:%22point%22,%22point%22:%5B83968.0,53553.0,302.0%5D,%22id%22:%2255059105b917d25c5374adea77647afcd15521c2%22,%22 ...

# %% [markdown]
# ## Most outputs

# %% [markdown]
# Lets repeat the exercise to find cells with the most outputs

# %%
pre_neuron_syn_df = syn_df[syn_df.pre_root_id.isin(neuron_df.pt_root_id)]
out_degree_df = pre_neuron_syn_df.groupby('pre_root_id').post_root_id.count()

# %% [markdown]
# in contrast to inputs only 15,884 outputs of the
#
# 3.2 million synapses can be connected
#
# to cells with cell bodies in volume

# %%
pre_neuron_syn_df.shape
# Out:
# (15884, 16)

# %% [markdown]
# ## Scatter plot: # inputs vs. # outputs

# %% [markdown]
# since we have the data, lets make a dataframe with all the cells in degree
# and out degree

# %%
in_out_df = pd.DataFrame({'in_degree': in_degree_df, 'out_degree':out_degree_df})

# %% [markdown]
# merge in the cell type information we have on these cells

# %%
in_out_ct_df = pd.merge(in_out_df, soma_df[['cell_type','pt_root_id']], left_index=True, right_on='pt_root_id' )

# %% [markdown]
# you can see here that many cells have low out-degree
# as excitatory neurons in the bottom half of the dataset
# have axons which leave the bottom of the volume
# before branching, but there are 5 inhibitory neurons with >300 synapses
#
# the in degree varies from a few hundred to >5000 depending on how much
# dendrite is in the volume

# %%
pg=sns.pairplot(x_vars=['in_degree'], y_vars=['out_degree'],
             data=in_out_ct_df, hue='cell_type', plot_kws={'alpha': 0.75},  height=5)

# %%
in_out_ct_df.query('out_degree>300')
# Out:
#      in_degree  out_degree cell_type          pt_root_id
# 319       4831      1082.0         i  648518346349528994
# 315       2459       516.0         i  648518346349538179
# 175       2698       386.0         i  648518346349538791
# 340       4891      1475.0         i  648518346349539215
# 185       3172       761.0         i  648518346349539846

# %% [markdown]
# let's get all these synapses from these neurons

# %%
is_from_most_out = pre_neuron_syn_df.pre_root_id.isin(in_out_ct_df.query('out_degree>300').pt_root_id.values)
most_inh_syn_out = pre_neuron_syn_df[is_from_most_out].copy()

# %% [markdown]
# here are our 4220 synapses

# %%
most_inh_syn_out.shape
# Out:
# (4220, 16)

# %% [markdown]
# ## Visualization: inhibitory cells with > 300 output synapses

# %% [markdown]
# lets visualize them all in neuroglancer

# %%
most_inh_syn_out['ctr_pos']=most_inh_syn_out.apply(lambda x: [x.ctr_pos_x_vx, x.ctr_pos_y_vx, x.ctr_pos_z_vx], axis=1).values

seg_layer = SegmentationLayerConfig(name = 'seg',
                                    source = seg_source,
                                    selected_ids_column='pre_root_id')

# setup a mapping rule for point annotations
syn_points = PointMapper(point_column='ctr_pos', linked_segmentation_column='post_root_id')
# add these points linked to the segmentation layer name
syn_layer = AnnotationLayerConfig(name='synapses', mapping_rules=syn_points, linked_segmentation_layer='seg')

sb = StateBuilder([img_layer, seg_layer, syn_layer])
# returning the link as an html link
sb.render_state(most_inh_syn_out, return_as='html')
# Out:
# <a href="https://neuromancer-seung-import.appspot.com/#!%7B%22navigation%22:%7B%22pose%22:%7B%22position%22:%7B%22voxelSize%22:%5B4.0,4.0,40.0%5D%7D%7D,%22zoomFactor%22:2.0%7D,%22showSlices%22:false,%22layout%22:%22xy-3d%22,%22perspectiveZoom%22:2000.0,%22layers%22:%5B%7B%22type%22:%22image%22,%22source%22:%22precomputed://https://storage.googleapis.com/microns_public_datasets/pinky100_v0/son_of_alignment_v15_rechunked%22,%22name%22:%22layer23%22%7D,%7B%22type%22:%22segmentation%22,%22source%22:%22precomputed://gs://microns_public_datasets/pinky100_v185/seg%22,%22name%22:%22seg%22,%22segments%22:%5B%22648518346349528994%22,%22648518346349538179%22,%22648518346349539846%22,%22648518346349538791%22,%22648518346349539215%22%5D,%22segmentColors%22:%7B%7D,%22selectedAlpha%22:0.3,%22objectAlpha%22:1.0,%22notSelectedAlpha%22:0.0%7D,%7B%22type%22:%22annotation%22,%22linkedSegmentationLayer%22:%22seg%22,%22filterBySegmentation%22:false,%22bracketShortcutsShowSegmentation%22:true,%22annotationSelectionShowsSegmentation%22:true,%22name%22:%22synapses%22,%22annotations%22:%5B%7B%22tagIds%22:%5B%5D,%22type%22:%22point%22,%22point%22:%5B61272.0,38797.0,1672.0%5D,%22id%22:%22e976f49f8a066c399869576ccc9c301183558cb9%22,%22segments%22:%5B%22648518346349538290%22%5D%7D,%7B%22tagIds%22:%5B%5D,%22type%22:%22point%22,%22point%22:%5B66226.0,40624.0,1829.0%5D,%22id%22:%229e4e37c21fcaeb0838a0880854c70a3808b83b71%22,%22segments%22:%5B%22648518346342808283%22%5D%7D,%7B%22tagIds%22:%5B%5D,%22type%22:%22point%22,%22point%22:%5B69566.0,48944.0,1818.0%5D,%22id%22:%224b781678bd5b4537b188e5cdc1b1662d96759dd8%22,%22segments%22:%5B%22648518346346304831%22%5D%7D,%7B%22tagIds%22:%5B%5D,%22type%22:%22point%22,%22point%22:%5B70014.0,61334.0,1629.0%5D,%22id%22:%2246341279c3c30c54cc387474af9d90b68a0eba5e%22,%22segments%22:%5B%22648518346341418659%22%5D%7D,%7B%22tagIds%22:%5B%5D,%22type%22:%22point%22,%22point%22:%5B59332.0,42528.0,1410.0%5D,%22id%22:%22f7e953dbd497fcdb830e956fdc2677e279828f6b%22,%22segments%22:%5B%22648518346349537921%22%5D%7D,%7B%22tagIds%22:%5B%5D,%22type%22:%22point%22,%22point%22:%5B60436.0,37460.0,1691.0%5D,%22id%22:%22bf6527ae5939afba56986490ae7a1e4390e225ef%22,%22segments%22:%5B%22648518346349539846%22%5D%7D,%7B%22tagIds%22:%5B%5D,%22type%22:%22point%22,%22point%22:%5B72270.0,53439.0,1568.0%5D,%22id%22:%222a172ee5ce6676e65d9c10075d6b0b072c7f3a63%22,%22segments%22:%5B%22648518346346299751%22%5D%7D,%7B%22tagIds%22:%5B%5D,%22type%22:%22point%22,%22point%22:%5B68046.0,45198.0,1113.0%5D,%22id%22:%2257e12cfaa898c573f5d52adb6399d7a7bfbc701e%22,%22segments%22:%5B%22648518346342934514%22%5D%7D,%7B%22tagIds%22:%5B%5D,%22type%22:%22point%22,%22point%22:%5B59150.0,45782.0,1308.0%5D,%22id%22:%22fdbfc42ad719b4dad9745a04e782203a11b3cac2%22,%22segments%22:%5B%22648518346342915657%22%5D%7D,%7B%22tagIds%22:%5B%5D,%22type%22:%22point%22,%22point%22:%5B67398.0,38878.0,560.0%5D,%22id%22:%22cf203feb3ac137d1fd8fc6badf410c4433b3c8b5%22,%22segments%22:%5B%22648518346347855222%22%5D%7D,%7B%22tagIds%22:%5B%5D,%22type%22:%22point%22,%22point%22:%5B64372.0,55482.0,1292.0%5D,%22id%22:%2255f2b062e85b86a0af42e3fdacbf02f0ac3bf3ec%22,%22segments%22:%5B%22648518346349515986%22%5D%7D,%7B%22tagIds%22:%5B%5D,%22type%22:%22point%22,%22point%22:%5